# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusuprozimemet/GPS_Ancestry_Migration_Map/blob/main/Royality_breakdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Interesting results from MytrueAncestry. I organized the data made my own plot, here it is.

import plotly.graph_objects as go

# Data
names = [
    "Arpad Dynasty",
    "House of Manfredi",
    "Kohanim",
    "House of Gontaut",
    "Clan Kinnaird",
    "Scottish Royalty",
    "House of Curiel",
    "House Percival",
    "Grand Dukes of Lithuania",
    "Persian Royalty",
    "Zhou Dynasty"
]

percentages = [
    39.4, 38.6, 13.2, 3.33, 1.95, 1.15, 0.67, 0.62, 0.38, 0.27, 0.24
]

# Location mapping
locations = {
    "Arpad Dynasty": "Hungary",
    "House of Manfredi": "Sicily, Italy",
    "Kohanim": "Various (Jewish diaspora)",
    "House of Gontaut": "Gascony, France",
    "Clan Kinnaird": "Perth and Kinross, Scotland",
    "Scottish Royalty": "Scotland",
    "House of Curiel": "Spain (Sephardic Jewish origin)",
    "House Percival": "England (Arthurian legends)",
    "Grand Dukes of Lithuania": "Lithuania",
    "Persian Royalty": "Persia (modern-day Iran)",
    "Zhou Dynasty": "China"
}

# Create the figure
fig = go.Figure()

# Add horizontal bars
fig.add_trace(go.Bar(
    y=names,
    x=percentages,
    orientation='h',
    text=[f'{p:.1f}% ({locations[n]})' for p, n in zip(percentages, names)],
    textposition='outside',
    hoverinfo='text',
    hovertext=[f'{name}<br>Percentage: {percentage:.2f}%<br>Location: {locations[name]}' for name, percentage in zip(names, percentages)]
))

# Customize the layout
fig.update_layout(
    title='Royality Breakdown by Y DNA',
    xaxis_title='Percentage',
    yaxis_title='Dynasty/Family',
    height=600,
    width=800,
    bargap=0.2,
    bargroupgap=0.1,
    yaxis={'categoryorder': 'total ascending'},
    uniformtext_minsize=8,
    uniformtext_mode='hide',
    xaxis_range=[0, 60]  # Set x-axis range from 0 to 50
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Data
names = [
    "Danish Royalty",
    "Belgian Royalty",
    "Sardinian Royalty",
    "Swedish Royalty",
    "Kings of Saxony",
    "Austrian Royalty",
    "Spanish Royalty",
    "Grand Princes of Kiev",
    "Prussian Royalty",
    "Holy Roman Empire",
    "Bohemian Royalty",
    "French Royalty",
    "Scottish Royalty",
    "German Royalty"
]

percentages = [
    8.67, 4.93, 4.93, 4.40, 4.26, 7.61, 7.61, 3.73, 4.93, 4.93, 3.34, 11.3, 2.67, 2.67
]

# Location mapping
locations = {
    "Danish Royalty": "Denmark",
    "Belgian Royalty": "Belgium",
    "Sardinian Royalty": "Sardinia, Italy",
    "Swedish Royalty": "Sweden",
    "Kings of Saxony": "Saxony, Germany",
    "Austrian Royalty": "Austria",
    "Spanish Royalty": "Spain",
    "Grand Princes of Kiev": "Kiev, Ukraine",
    "Prussian Royalty": "Prussia, Germany",
    "Holy Roman Empire": "Various (Central Europe)",
    "Bohemian Royalty": "Bohemia, Czech Republic",
    "French Royalty": "France",
    "Scottish Royalty": "Scotland",
    "German Royalty": "Germany"
}

# Create the figure
fig = go.Figure()

# Add horizontal bars
fig.add_trace(go.Bar(
    y=names,
    x=percentages,
    orientation='h',
    text=[f'{p:.1f}% ({locations[n]})' for p, n in zip(percentages, names)],
    textposition='outside',
    hoverinfo='text',
    hovertext=[f'{name}<br>Percentage: {percentage:.2f}%<br>Location: {locations[name]}' for name, percentage in zip(names, percentages)]
))

# Customize the layout
fig.update_layout(
    title='Royalty Breakdown by mtDNA',
    xaxis_title='Percentage',
    yaxis_title='Royalty',
    height=600,
    width=800,
    bargap=0.2,
    bargroupgap=0.1,
    yaxis={'categoryorder': 'total ascending'},
    uniformtext_minsize=8,
    uniformtext_mode='hide',
    xaxis_range=[0, 15]  # Adjusted x-axis range to fit the new data
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# The actual data from your list
data = {
    'Dynasty/House': ['Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Gontaut', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Clan Kinnaird', 'Clan Kinnaird', 'Scottish Royalty', 'Scottish Royalty', 'House of Curiel', 'House Percival', 'Grand Dukes of Lithuania', 'Persian Royalty', 'Zhou Dynasty'],
    'Sample Location': ['Kazakhstan, Kyzylshilik', 'Mongolia, Tavan Tolgoi', 'Hidden - Upgrade Needed', 'Hidden - Upgrade Needed', 'Russia, Early Sarmatian', 'Russia, Andronovo Culture', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Mongolia, Uguumur Uul', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hidden - Upgrade Needed', 'Kazakhstan, Karakaba', 'Russia, Shekshovo', 'Iron Age Alai Nura Burial', 'Hungary, Derecske-Hosszu', 'Russia, Shekshovo', 'Hungary, Rakoczifalva', 'Russia, Shekshovo'],
    'Date': ['660 BC', '1300 AD', '-', '-', '300 BC', '1300 BC', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '50 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '850 AD', '1200 AD', '300 AD', '750 AD', '1200 AD', '650 AD', '1200 AD'],
    'Sample ID': ['KYZ001', 'TAV011', 'BKT001', 'ARS026', '10247', '111540', 'RKF198', 'RKC039', 'RKF218', 'RKF127', 'RKC047', 'RKF015', 'RKC045', 'RKF046', 'RKF020', 'RKC028', 'RKF213', 'RKC038', 'RKF047', 'RKF032', 'RKF157', 'UGU006', 'RKFI21', 'RKF194', 'RKF110', 'RKF129', 'RKC021', 'RKF124', 'RKF147', 'RKF098', 'RKF117', 'RKF062', 'RKF053', 'RKF237', 'RKF226', 'RKF182', 'RKF192', 'RKC051', 'RKC052', 'KKB001', 'SHK001', 'ALN008', '120799', 'SHK002', 'RKF230', 'SHK002'],
    'Genetic Distance': [14.78, 14.99, 16.83, 17.26, None, None, 11.14, 11.75, 11.90, 12.49, 12.86, 13.01, 13.22, 13.45, 13.53, 14.10, 14.28, 14.34, 14.67, 14.89, 15.02, 11.46, 11.43, 12.42, 13.02, 13.17, 13.24, 13.25, 14.55, 14.71, 15.07, 15.38, 15.51, 15.83, 16.54, 17.20, 17.38, 15.14, 16.72, 14.22, 15.15, 13.65, 14.79, 14.72, 15.37, 14.72],
    'mtDNA': ['D4i', 'C4b1', 'C4a1b', 'C4a1a-a', 'G2a4', 'Ala', 'J1b1a', 'G2a1', 'H7a1', None, 'N9a9', 'T2+16189', 'HV2a1', 'V7a', None, None, 'M8a2b', 'D4j+16311', 'C4a1a4', None, None, 'Z1a', 'K1b2a2', 'K1b2a2', 'H55', 'D4c2b', 'G2a1', 'D4j+16311', 'J2a2a', 'F1b1b', 'U5b1b1+16192', None, None, 'J2a2a', 'J2a2a', 'H6a1a', 'H26', None, None, 'T2c1-a1', 'M9a1a', 'D4j', 'U5a2e', 'Z3c', 'J1b1a', 'Z3c'],
    'Y-DNA': ['R1a1a1b2a', 'R1a1a1b2a2a', 'R1a1a1b2a', 'R1a1a1b2a2a', 'R1a1a1b2a2a', 'R1a1a1b2a2a1d1', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', None, 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', None, None, 'J1a2a1a2d2b2b2c4b', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', None, None, None, 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', None, 'K1a4a1a+195 R1a1a1b1a2b3a', 'J2a', 'J2a', 'E1b1b1b2a1', 'E1b1b1a1b1', 'N1', 'J1a', 'N1']
}

# %%
import pandas as pd

# The original dataset
data = {
    'Dynasty/House': ['Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty', 'Arpad Dynasty',
                      'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi',
                      'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi',
                      'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi', 'House of Manfredi',
                      'House of Gontaut', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim',
                      'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim', 'Kohanim',
                      'Kohanim', 'Kohanim', 'Clan Kinnaird', 'Clan Kinnaird',
                      'Scottish Royalty', 'Scottish Royalty',
                      'House of Curiel', 'House Percival',
                      'Grand Dukes of Lithuania',
                      'Persian Royalty',
                      'Zhou Dynasty'],
    'Sample Location': ['Kazakhstan, Kyzylshilik', 'Mongolia, Tavan Tolgoi', 'Hidden - Upgrade Needed', 'Hidden - Upgrade Needed', 'Russia, Early Sarmatian', 'Russia, Andronovo Culture', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Mongolia, Uguumur Uul', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hungary, Rakoczifalva', 'Hidden - Upgrade Needed', 'Kazakhstan, Karakaba', 'Russia, Shekshovo', 'Iron Age Alai Nura Burial', 'Hungary, Derecske-Hosszu', 'Russia, Shekshovo', 'Hungary, Rakoczifalva', 'Russia, Shekshovo'],
    'Date': ['660 BC', '1300 AD', '-', '-', '300 BC', '1300 BC', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '50 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '650 AD', '850 AD', '1200 AD', '300 AD', '750 AD', '1200 AD', '650 AD', '1200 AD'],
    'Sample ID': ['KYZ001', 'TAV011', 'BKT001', 'ARS026', '10247', '111540', 'RKF198', 'RKC039', 'RKF218', 'RKF127', 'RKC047', 'RKF015', 'RKC045', 'RKF046', 'RKF020', 'RKC028', 'RKF213', 'RKC038', 'RKF047', 'RKF032', 'RKF157', 'UGU006', 'RKFI21', 'RKF194', 'RKF110', 'RKF129', 'RKC021', 'RKF124', 'RKF147', 'RKF098', 'RKF117', 'RKF062', 'RKF053', 'RKF237', 'RKF226', 'RKF182', 'RKF192', 'RKC051', 'RKC052', 'KKB001', 'SHK001', 'ALN008', '120799', 'SHK002', 'RKF230', 'SHK002'],
    'Genetic Distance': [14.78, 14.99, 16.83, 17.26, None, None, 11.14, 11.75, 11.90, 12.49, 12.86, 13.01, 13.22, 13.45, 13.53, 14.10, 14.28, 14.34, 14.67, 14.89, 15.02, 11.46, 11.43, 12.42, 13.02, 13.17, 13.24, 13.25, 14.55, 14.71, 15.07, 15.38, 15.51, 15.83, 16.54, 17.20, 17.38, 15.14, 16.72, 14.22, 15.15, 13.65, 14.79, 14.72, 15.37, 14.72],
    'mtDNA': ['D4i', 'C4b1', 'C4a1b', 'C4a1a-a', 'G2a4', 'Ala', 'J1b1a', 'G2a1', 'H7a1', None, 'N9a9', 'T2+16189', 'HV2a1', 'V7a', None, None, 'M8a2b', 'D4j+16311', 'C4a1a4', None, None, 'Z1a', 'K1b2a2', 'K1b2a2', 'H55', 'D4c2b', 'G2a1', 'D4j+16311', 'J2a2a', 'F1b1b', 'U5b1b1+16192', None, None, 'J2a2a', 'J2a2a', 'H6a1a', 'H26', None, None, 'T2c1-a1', 'M9a1a', 'D4j', 'U5a2e', 'Z3c', 'J1b1a', 'Z3c'],
    'Y-DNA': ['R1a1a1b2a', 'R1a1a1b2a2a', 'R1a1a1b2a', 'R1a1a1b2a2a', 'R1a1a1b2a2a', 'R1a1a1b2a2a1d1', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', None, 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', 'J2b2a1a1a1a1a1e', None, None, 'J1a2a1a2d2b2b2c4b', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', None, None, None, 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', 'J1a2a1a2d2b2b2', None, 'K1a4a1a+195 R1a1a1b1a2b3a', 'J2a', 'J2a', 'E1b1b1b2a1', 'E1b1b1a1b1', 'N1', 'J1a', 'N1']
}

# Find the maximum length among all columns
max_length = max(len(column) for column in data.values())

# Pad all columns to the same length with None values
for key in data:
    data[key] += [None] * (max_length - len(data[key]))

# Load data into a DataFrame
df = pd.DataFrame(data)

# Replace missing or invalid dates with a placeholder
df['Date'] = df['Date'].replace('-', None).fillna('Unknown')

# Function to convert dates to numeric values for sorting
def process_date(date):
    if date == "Unknown":
        return float('inf')  # Place unknown dates at the end
    elif "BC" in date:
        return -int(date.replace(" BC", ""))  # Convert BC to negative years
    elif "AD" in date:
        return int(date.replace(" AD", ""))  # Convert AD to positive years
    else:
        return float('inf')  # Handle any other unexpected formats

# Apply the function to create a sortable column
df['Sortable Date'] = df['Date'].apply(process_date)

# Sort the DataFrame by the sortable date column
df_sorted = df.sort_values(by='Sortable Date').drop(columns=['Sortable Date'])

# Reset index for a clean DataFrame
df_sorted.reset_index(drop=True, inplace=True)

# Display the sorted DataFrame
print(df_sorted)
df_sorted=df
# Out:
#                Dynasty/House            Sample Location     Date Sample ID  \
# 0              Arpad Dynasty  Russia, Andronovo Culture  1300 BC    111540
# 1              Arpad Dynasty    Kazakhstan, Kyzylshilik   660 BC    KYZ001
# 2              Arpad Dynasty    Russia, Early Sarmatian   300 BC     10247
# 3           House of Gontaut      Mongolia, Uguumur Uul    50 AD    UGU006
# 4            House of Curiel  Iron Age Alai Nura Burial   300 AD    SHK001
# 5                    Kohanim      Hungary, Rakoczifalva   650 AD    RKF110
# 6                    Kohanim      Hungary, Rakoczifalva   650 AD    RKF129
# 7                    Kohanim      Hungary, Rakoczifalva   650 AD    RKC021
# 8                    Kohanim      Hungary, Rakoczifalva   650 AD    RKF124
# 9                    Kohanim      Hungary, Rakoczifalva   650 AD    RKF147
# 10                   Kohanim      Hungary, Rakoczifalva   650 AD    RKF098
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Load the sorted DataFrame
df = df_sorted

# Replace missing values for plotting purposes
df['Genetic Distance'] = df['Genetic Distance'].fillna(0)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='Dynasty/House', order=df['Dynasty/House'].value_counts().index, palette='viridis')
plt.title('Number of Samples per Dynasty/House')
plt.xlabel('Count')
plt.ylabel('Dynasty/House')
plt.show()
# Out:
# <ipython-input-32-1a9d83c5c251>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
import plotly.graph_objects as go
import pandas as pd

# Assuming 'df' is your DataFrame, 'percentages' is a list of percentage values, and 'names' is a list of labels

# Plot 1: Actual counts
dynasty_counts = df['Dynasty/House'].value_counts()
fig1 = go.Figure(data=[go.Pie(labels=dynasty_counts.index,
                              values=dynasty_counts.values,
                              textinfo='percent',
                              insidetextorientation='radial',
                              marker=dict(colors=px.colors.qualitative.Pastel))])
fig1.update_layout(title='Actual Counts')

# Plot 2: Given Percentages
fig2 = go.Figure(data=[go.Pie(labels=names,
                              values=percentages,
                              textinfo='percent+label',
                              insidetextorientation='radial',
                              marker=dict(colors=px.colors.qualitative.Set1))])
fig2.update_layout(title='Provided Percentages')

# Displaying both plots
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Create an interactive scatter plot
fig = px.scatter(
    df,
    x='Numeric Date',  # X-axis: Numeric representation of date (BC/AD)
    y='Genetic Distance',  # Y-axis: Genetic Distance
    color='Dynasty/House',  # Grouping by Dynasty/House
    hover_data=['Sample Location', 'Date', 'Sample ID', 'mtDNA', 'Y-DNA'],  # Additional info on hover
    title='Interactive Scatter Plot: Genetic Distance vs Date',
    labels={'Numeric Date': 'Year', 'Genetic Distance': 'Genetic Distance'},  # Axis labels
    template='plotly'  # Styling template
)

# Customize layout for better visualization
fig.update_layout(
    legend_title_text='Dynasty/House',
    xaxis_title='Year',
    yaxis_title='Genetic Distance',
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True)
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=df, x='Dynasty/House', y='Genetic Distance', palette='coolwarm')
plt.title('Distribution of Genetic Distance by Dynasty/House')
plt.xticks(rotation=45)
plt.ylabel('Genetic Distance')
plt.xlabel('Dynasty/House')
plt.show()
# Out:
# <ipython-input-35-f4e24697f208>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Genetic Distance'], bins=20, kde=True, color='blue')
plt.title('Distribution of Genetic Distances')
plt.xlabel('Genetic Distance')
plt.ylabel('Frequency')
plt.show()

# %%
top_mtdna = df['mtDNA'].value_counts().head(10)  # Top 10 mtDNA haplogroups

plt.figure(figsize=(12, 6))
sns.barplot(x=top_mtdna.index, y=top_mtdna.values, palette='magma')
plt.title('Top 10 mtDNA Haplogroups')
plt.xlabel('mtDNA Haplogroup')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-38-910486848a69>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
top_ydna = df['Y-DNA'].value_counts().head(10)  # Top 10 Y-DNA haplogroups

plt.figure(figsize=(12, 6))
sns.barplot(x=top_ydna.index, y=top_ydna.values, palette='cividis')
plt.title('Top 10 Y-DNA Haplogroups')
plt.xlabel('Y-DNA Haplogroup')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-39-463deaa1756d>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
location_counts = df['Sample Location'].value_counts().head(10)  # Top 10 locations

plt.figure(figsize=(12, 6))
sns.barplot(x=location_counts.values, y=location_counts.index, palette='plasma')
plt.title('Top Sample Locations by Count')
plt.xlabel('Count')
plt.ylabel('Sample Location')
plt.show()
# Out:
# <ipython-input-40-81c3f02d246c>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
import folium
from folium import plugins
import math

# Create a base map with a sophisticated tile layer
m = folium.Map(
    location=[48, 10],
    zoom_start=4,
    tiles='cartodb positron'
)

# Add scale bar
folium.plugins.MiniMap().add_to(m)
folium.plugins.Fullscreen().add_to(m)

# Predefined coordinates
coordinates = {
    # Y-DNA locations
    "Arpad Dynasty": (47.1625, 19.5033),
    "House of Manfredi": (37.5999, 14.0154),
    "Kohanim": (31.7683, 35.2137),
    "House of Gontaut": (44.8378, 0.4814),
    "Clan Kinnaird": (56.3950, -3.4308),
    "Scottish Royalty (Y-DNA)": (56.4907, -4.2026),
    "House of Curiel": (40.4168, -3.7038),
    "House Percival": (51.5074, -0.1278),
    "Grand Dukes of Lithuania": (54.6872, 25.2797),
    "Persian Royalty": (35.6892, 51.3890),
    "Zhou Dynasty": (34.3416, 108.9398),
    # mt-DNA locations
    "Danish Royalty": (55.6761, 12.5683),
    "Belgian Royalty": (50.8503, 4.3517),
    "Sardinian Royalty": (39.2238, 9.1217),
    "Swedish Royalty": (59.3293, 18.0686),
    "Kings of Saxony": (51.0504, 13.7373),
    "Austrian Royalty": (48.2082, 16.3738),
    "Spanish Royalty": (40.4165, -3.7026),
    "Grand Princes of Kiev": (50.4501, 30.5234),
    "Prussian Royalty": (52.5200, 13.4050),
    "Holy Roman Empire": (48.2082, 16.3738),
    "Bohemian Royalty": (50.0755, 14.4378),
    "French Royalty": (48.8566, 2.3522),
    "German Royalty": (52.5200, 13.4050),
    "Scottish Royalty (mtDNA)": (56.4907, -4.4026)  # Slightly offset to avoid overlap
}

# Separate Y-DNA and mt-DNA data
y_dna_data = {
    "Arpad Dynasty": 39.4,
    "House of Manfredi": 38.6,
    "Kohanim": 13.2,
    "House of Gontaut": 3.33,
    "Clan Kinnaird": 1.95,
    "Scottish Royalty (Y-DNA)": 1.15,
    "House of Curiel": 0.67,
    "House Percival": 0.62,
    "Grand Dukes of Lithuania": 0.38,
    "Persian Royalty": 0.27,
    "Zhou Dynasty": 0.24
}

mt_dna_data = {
    "Danish Royalty": 8.67,
    "Belgian Royalty": 4.93,
    "Sardinian Royalty": 4.93,
    "Swedish Royalty": 4.40,
    "Kings of Saxony": 4.26,
    "Austrian Royalty": 7.61,
    "Spanish Royalty": 7.61,
    "Grand Princes of Kiev": 3.73,
    "Prussian Royalty": 4.93,
    "Holy Roman Empire": 4.93,
    "Bohemian Royalty": 3.34,
    "French Royalty": 11.3,
    "German Royalty": 2.67,
    "Scottish Royalty (mtDNA)": 2.67
}

# Function to determine circle size based on percentage
def get_circle_radius(percentage):
    return math.sqrt(percentage) * 5

# Add Y-DNA markers (in blue)
for dynasty, percentage in y_dna_data.items():
    coords = coordinates[dynasty]

    folium.CircleMarker(
        location=coords,
        radius=get_circle_radius(percentage),
        popup=f"{dynasty}<br>Y-DNA Percentage: {percentage:.2f}%",
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.4,
        weight=2,
        tooltip=f"{dynasty} (Y-DNA)"
    ).add_to(m)

    if percentage > 5:
        folium.Popup(
            f"{dynasty}<br>{percentage:.1f}% (Y-DNA)",
            permanent=True
        ).add_to(folium.CircleMarker(
            location=coords,
            radius=1,
            color='transparent',
            fill=False
        ).add_to(m))

# Add mt-DNA markers (in purple)
for dynasty, percentage in mt_dna_data.items():
    coords = coordinates[dynasty]

    folium.CircleMarker(
        location=coords,
        radius=get_circle_radius(percentage),
        popup=f"{dynasty}<br>mtDNA Percentage: {percentage:.2f}%",
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.4,
        weight=2,
        tooltip=f"{dynasty} (mtDNA)"
    ).add_to(m)

    if percentage > 5:
        folium.Popup(
            f"{dynasty}<br>{percentage:.1f}% (mtDNA)",
            permanent=True
        ).add_to(folium.CircleMarker(
            location=coords,
            radius=1,
            color='transparent',
            fill=False
        ).add_to(m))

# Add a legend with both DNA types
legend_html = '''
<div style="position: fixed;
            bottom: 50px; left: 50px; width: 220px; height: 160px;
            border:2px solid grey; z-index:9999;
            background-color:white;
            padding: 10px;
            font-size: 14px;">
            <b>DNA Type & Percentage</b><br>
            <i class="fa fa-circle" style="color:red"></i> Y-DNA Large (>30%)<br>
            <i class="fa fa-circle" style="color:red;opacity:0.7"></i> Y-DNA Medium (10-30%)<br>
            <i class="fa fa-circle" style="color:red;opacity:0.4"></i> Y-DNA Small (<10%)<br>
            <i class="fa fa-circle" style="color:green"></i> mtDNA Large (>10%)<br>
            <i class="fa fa-circle" style="color:green;opacity:0.7"></i> mtDNA Medium (5-10%)<br>
            <i class="fa fa-circle" style="color:green;opacity:0.4"></i> mtDNA Small (<5%)
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

# Add title
title_html = '''
<div style="position: fixed;
            top: 10px; left: 50%; transform: translateX(-50%);
            z-index:9999; background-color:white;
            padding: 10px; border:2px solid grey;
            font-size: 16px; font-weight: bold;">
            Royal DNA Distribution Map (Red: Y-DNA, Green: mtDNA)
</div>
'''
m.get_root().html.add_child(folium.Element(title_html))

# Save map
m.save('enhanced_royalty_map.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
